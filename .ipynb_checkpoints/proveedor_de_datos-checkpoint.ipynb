# %% [markdown]
# ### Installing and importing libraries

# %%
# !pip3 install yfinance
# !pip3 install pandas
# !pip3 install matplotlib
# !pip3 install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 29.6 MB/s eta 0:00:00a 0:00:01
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# ...

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Here I just want to prove the yfinance library and plot it

# %%
ticker_symbol = 'AAPL'
stock_data = yf.download(ticker_symbol, period="14d")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
print(stock_data)
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2025-03-04  235.929993  240.070007  234.679993  237.710007  53798100
# 2025-03-05  235.740005  236.550003  229.229996  235.419998  47227600
# 2025-03-06  235.330002  237.860001  233.160004  234.440002  45170400
# 2025-03-07  239.070007  241.369995  234.759995  235.110001  46273600
# 2025-03-10  227.479996  236.160004  224.220001  235.539993  72071200
# 2025-03-11  220.839996  225.839996  217.449997  223.809998  76137400
# 2025-03-12  216.979996  221.750000  214.910004  220.139999  62547500
# 2025-03-13  209.679993  216.839996  208.419998  215.949997  61368300
# 2025-03-14  213.490005  213.949997  209.580002  211.250000  60107600
# 2025-03-17  214.000000  215.220001  209.970001  213.309998  48073400
# 2025-03-18  212.690002  215.149994  211.490005  214.160004  42432400
# ...

# %%
plt.figure(figsize=(14, 10))

plt.subplot(2, 1, 1)
plt.plot(stock_data['Open'], label='Open Price', marker='o')
plt.plot(stock_data['High'], label='High Price', marker='o')
plt.plot(stock_data['Low'], label='Low Price', marker='o')
plt.plot(stock_data['Close'], label='Close Price', marker='o')
plt.title(f'{ticker_symbol} Stock Prices (Last 1 Month)')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# ### Aqui empiezo el modelo de linear regression

# %% [markdown]
# The first thing that comes to my mind is using 15 days prev info in the closing prize to predict the next closing prize.

# %%
close = stock_data['Close']
for i in close:
    print(i)
# Out:
# AAPL
